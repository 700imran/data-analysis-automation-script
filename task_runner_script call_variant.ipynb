# %%
import pandas as pd
from task_runner import run_task
run_task("comparison")

# %%
import pandas as pd
from task_runner import run_task
run_task("scenario")

# %%
import pandas as pd
from task_runner import run_task
run_task("relation")

# %%
import pandas as pd
from task_runner import run_task
run_task("kpi")

# %%
import pandas as pd
from task_runner import run_task
run_task("model")

# %%
from task_runner import run_task

# Run the 3-statement model through the runner
results = run_task("model", filepath=None)

print("Enterprise Value:", results["enterprise_value"])
