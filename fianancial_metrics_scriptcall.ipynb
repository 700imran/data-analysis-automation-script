# %%
from financial_metrics_utils import get_assumptions

ticker = "TCS.NS"
print(get_assumptions(ticker))
# Out:
# {'Growth Rate': np.float64(-9.0), 'COGS %': np.float64(54.41), 'Opex %': np.float64(20.96), 'Tax Rate': 'N/A', 'Capex %': np.float64(-1.4), 'Depreciation %': np.float64(1.97), 'Working Capital %': 'N/A', 'Discount Rate (CAPM)': 8.62}
