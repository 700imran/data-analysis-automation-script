# %%
from kpi_utils import valuation_kpis
df = valuation_kpis("WMT")
print(df)
# Out:
#   Ticker       CMP   EPS    P/E   P/B  Earnings Yield (%)  Dividend Yield (%)  \
# 0    WMT  115.6163  2.86  40.43  9.59                2.47                0.81
#
#    Gov Bond Yield (%)   Valuation
# 0                 7.0  Overvalued
