# %%
from industry_benchmark_forecast_utils import forecast_with_industry

forecast_df, ev, npv = forecast_with_industry("Technology", revenue=2_000_000, years=5)
print(forecast_df)
print("Enterprise Value:", ev)
print("NPV:", npv)
# Out:
# Revenue data not found — using fallback growth rate.
#    Year      Revenue         COGS        Opex  Depreciation      EBIT  \
# 0     1  2100000.000  1260000.000  420000.000     84000.000  336000.0
# 1     2  2205000.000  1323000.000  441000.000     88200.000  352800.0
# 2     3  2315250.000  1389150.000  463050.000     92610.000  370440.0
# 3     4  2431012.500  1458607.500  486202.500     97240.500  388962.0
# 4     5  2552563.125  1531537.875  510512.625    102102.525  408410.1
#
#    Net Income         Capex  Working Capital Change  Free Cash Flow  \
# 0   235200.00  105000.00000             210000.0000      4200.00000
# 1   246960.00  110250.00000             220500.0000      4410.00000
# 2   259308.00  115762.50000             231525.0000      4630.50000
# 3   272273.40  121550.62500             243101.2500      4862.02500
# 4   285887.07  127628.15625             255256.3125      5105.12625
#
#    Discounted FCF
# 0     3750.000000
# 1     3515.625000
# 2     3295.898437
# ...
