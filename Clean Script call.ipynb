# %%
import pandas as pd
from primary_clean_utils import clean_dataframe

# Load any dataset even excel or csv file (only one df can be run at once xlsx or cvs not both )
df = pd.read_csv(r"D:\Users\DELL\Downloads\Stores.csv")
df = pd.read_excelfile(r"D:\Users\DELL\Downloads\Stores.xlsx")

# Clean it
df_clean = clean_dataframe(df)

# Now df_clean is ready for analysis
print(df_clean.head())
